# %%
import pandas as pd
import chardet
import numpy as np
pd.set_option('display.max_columns', None)

# detect the encoding
with open('/Users/cemakay/DataScience/Jupyter/Data/Superstore-Sales.csv', 'rb') as f:
    result = chardet.detect(f.read())
    
# read the file with the detected encoding
df = pd.read_csv('/Users/cemakay/DataScience/Jupyter/Data/Superstore-Sales.csv', encoding=result['encoding'])

# %%
df_pivot  = df.pivot_table(index='Province', values='Sales', aggfunc='sum', margins=True, margins_name='Total' ).reset_index()
#df_pivot

# %%
df.head(1)
# Out:
#    Row ID  Order ID  Order Date Order Priority  Order Quantity   Sales  \
# 0       1       NaN  10/13/2010            Low               6  261.54
#
#    Discount Ship Mode  Profit  Unit Price  Shipping Cost       Customer Name  \
# 0      0.04       NaN -213.25       38.94           35.0  Muhammed MacIntyre
#
#   Province   Region Customer Segment Product Category    Product Sub-Category  \
# 0  Nunavut  Nunavut   Small Business  Office Supplies  Storage & Organization
#
#                                        Product Name Product Container  \
# 0  Eldon Base for stackable storage shelf, platinum         Large Box
#
#    Product Base Margin   Ship Date
# 0                  0.8  10/20/2010

# %%
df['Product Container'].value_counts()
# Out:
# Product Container
# Small Box     4347
# Wrap Bag      1168
# Small Pack     956
# Jumbo Drum     624
# Jumbo Box      532
# Large Box      406
# Medium Box     366
# Name: count, dtype: int64

# %%
# Out:
#      Row ID  Order ID Order Date Order Priority  Order Quantity    Sales  \
# 46      670    4676.0  8/31/2011           High              50   187.83
# 72     1017    7430.0   6/8/2010         Medium              50   751.77
# 93     1445   10437.0  8/18/2009       Critical              50   820.52
# 138    2117   15108.0  8/27/2009           High              50  2066.16
# 267    4118   29287.0   7/2/2009           High              50   281.39
#
#      Discount    Ship Mode  Profit  Unit Price  Shipping Cost  \
# 46       0.03  Regular Air   85.96        3.75           0.50
# 72       0.05  Regular Air  353.20       15.67           1.39
# 93       0.01  Regular Air -191.22       15.99          13.18
# 138      0.02  Regular Air  372.36       40.99          17.48
# 267      0.10  Regular Air -106.40        5.74           5.01
#
#          Customer Name               Province                 Region  \
# 46        Annie Cyprus                Nunavut                Nunavut
# 72       Barry Weirich                Nunavut                Nunavut
# 93           Don Jones  Northwest Territories  Northwest Territories
# 138  Delfina Latchford  Northwest Territories  Northwest Territories
# 267       Edward Hooks  Northwest Territories  Northwest Territories
#
#     Customer Segment Product Category            Product Sub-Category  \
# 46       Home Office  Office Supplies                          Labels
# 72         Corporate  Office Supplies                       Envelopes
# 93         Corporate  Office Supplies  Binders and Binder Accessories
# 138   Small Business  Office Supplies                           Paper
# 267         Consumer  Office Supplies  Binders and Binder Accessories
#
#                                           Product Name Product Container  \
# 46                                           Avery 510         Small Box
# 72          #10 White Business Envelopes,4 1/8 x 9 1/2         Small Box
# 93   GBC Pre-Punched Binding Paper, Plastic, White,...         Small Box
# 138                                         Xerox 1893         Small Box
# 267                                       Binder Posts         Small Box
#
#      Product Base Margin  Ship Date
# 46                  0.37   9/2/2011
# 72                  0.38   6/9/2010
# 93                  0.37  8/20/2009
# 138                 0.36  8/29/2009
# 267                 0.39   7/4/2009
